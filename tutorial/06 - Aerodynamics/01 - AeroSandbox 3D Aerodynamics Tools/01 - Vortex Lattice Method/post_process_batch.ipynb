# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('batch_results.csv')
df
# Out:
#      span_m   chord_m  surface_area_m2  twist_root_deg  twist_slope_deg_per_m  \
# 0  2.785000  1.043307         5.811315        4.875752              -1.277383
# 1  3.094444  0.864101         5.347888        5.157261              -1.314807
# 2  3.403889  0.759650         5.171572        5.171989              -1.268356
# 3  3.713333  0.691538         5.135857        5.045104              -1.191312
# 4  4.022778  0.643314         5.175843        4.847579              -1.106141
# 5  4.332222  0.606819         5.257769        4.621491              -1.023023
# 6  4.641667  0.577701         5.363008        4.390165              -0.946130
# 7  4.951111  0.553505         5.480940        4.165525              -0.876710
# 8  5.260556  0.532769         5.605333        3.953076              -0.814687
# 9  5.570000  0.514580         5.732434        3.754889              -0.759455
#
#    tip_twist_deg  alpha_deg        CL        CD    L_over_D  S_CL
# 0       1.318241        0.0  0.516234  0.015649   32.988766   3.0
# 1       1.088664        0.0  0.560969  0.013859   40.476563   3.0
# 2       0.854646        0.0  0.580094  0.011900   48.748685   3.0
# 3       0.621366        0.0  0.584128  0.010108   57.790746   3.0
# 4       0.397818        0.0  0.579616  0.008575   67.592935   3.0
# 5       0.189528        0.0  0.570584  0.007301   78.147278   3.0
# 6      -0.001456        0.0  0.559388  0.006254   89.447137   3.0
# 7      -0.175164        0.0  0.547351  0.005393  101.487036   3.0
# 8      -0.332628        0.0  0.535205  0.004684  114.262487   3.0
# 9      -0.475273        0.0  0.523338  0.004096  127.769801   3.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['span_m'], df['twist_root_deg'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['span_m'], df['tip_twist_deg'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['span_m'], df['L_over_D'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['span_m'], df['CL'], label='CL')
plt.legend()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['span_m'], df['CD'], label='CD')
plt.legend()
